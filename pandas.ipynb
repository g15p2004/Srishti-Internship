# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in ./lib/python3.12/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)

# %%
lst = ['Alice', 25], ['Bob', 30]
df = pd.DataFrame(lst, columns=['Name', 'Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age'] > 25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender'] = ['F', 'M']

# %%
#df.drop('Age', axis=1, inplace=True)

# %%
df.isnull()
# Out:
#     Name    Age  Gender
# 0  False  False   False
# 1  False  False   False

# %%
df.dropna()
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.fillna(0)
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    25.0
# M    30.0
# Name: Age, dtype: float64

# %%
df1 = pd.DataFrame({
    'key': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David']
})
df2 = pd.DataFrame({
    'key': [1, 2, 3, 5],
    'Age': [25, 30, 35, 40]
})
pd.merge(df1, df2, on='key')
df1
# Out:
#    key     Name
# 0    1    Alice
# 1    2      Bob
# 2    3  Charlie
# 3    4    David

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['key', 'Name'], dtype='str')
# Index(['key', 'Age'], dtype='str')

# %%
df1.set_index('key').join(df2.set_index('key'))
# Out:
#         Name  Age
# key
# 1      Alice   25
# 2        Bob   30
# 3    Charlie   35

# %%
df.sort_values('Age')
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df['Age'].apply(lambda x: x + 1)
# Out:
# 0    26
# 1    31
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob']
# Length: 2, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# Name: count, dtype: int64
